# %%
import numpy as np
import pandas as pd
import time
import os
import warnings
import matplotlib.pyplot as plt

from aim.aimreg import AIMRegressor
from aim.stats_ppr import PPRRegressor

# %%
np.random.seed(2020)
n = int(1e4)
x = np.random.normal(0, 1, size=(n, 6))
beta = np.array([3, -2.5, 2, -1.5, 1.5, -1.0])/5
z = np.dot(x.reshape(-1,6),beta)
z1 = beta[0] * x[:, 0] + beta[1] * x[:, 1] + beta[2] * x[:, 2]
z2 = beta[3] * x[:, 3] + beta[4] * x[:, 4] + beta[4] * x[:, 4]
f = z1+0.5*z2**2
noise = np.random.randn(n)
y = f + noise

# %%
clf = PPRRegressor(nterms=2,optlevel=2)
clf.fit(x,y)
# Out:
# PPRRegressor(nterms=2)

# %%
clf.projection_indices_
# Out:
# array([[ 0.69619831,  0.01104373],
#        [-0.57259348,  0.00878713],
#        [ 0.43279482, -0.01564732],
#        [ 0.01048979,  0.4204885 ],
#        [-0.00361624, -0.90677896],
#        [-0.00318595, -0.02230096]])

# %%
clf.visualize()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y,clf.predict(x))
# Out:
# 0.9898630525405137
