# %%
import numpy as np

# %%
from statsgaim.stats_ppr import PPRRegressor

# %% [markdown]
# # SIM: Quadratic Function

# %%
np.random.seed(2020)
n = int(1e4)
x = np.random.normal(0, 1, size=(n, 6))
beta = np.array([3, -2.5, 2, -1.5, 1.5, -1.0])/5
z = np.dot(x.reshape(-1,6),beta)
f = z**2
noise = np.random.randn(n)
y = f + noise

# %%
clf = PPRRegressor(nterms=1,optlevel=2)
clf.fit(x,y)
# Out:
# PPRRegressor(nterms=1)

# %%
clf.projection_indices_
# Out:
# array([[ 0.60398208],
#        [-0.50480086],
#        [ 0.39743623],
#        [-0.30052682],
#        [ 0.30568276],
#        [-0.19664147]])

# %%
clf.visualize()

# %% [markdown]
# # AIM: Quadratic + Linear

# %%
np.random.seed(2020)
n = int(1e4)
x = np.random.normal(0, 1, size=(n, 6))
beta = np.array([3, -2.5, 2, -1.5, 1.5, -1.0])/5
z1 = beta[0] * x[:, 0] + beta[1] * x[:, 1] + beta[2] * x[:, 2]
z2 = beta[3] * x[:, 3] + beta[4] * x[:, 4] + beta[5] * x[:, 5]
f = z1+0.5*z2**2
noise = np.random.randn(n)
y = f + noise

# %%
clf2 = PPRRegressor(nterms=2,optlevel=2)
clf2.fit(x,y)
# Out:
# PPRRegressor(nterms=2)

# %%
clf2.projection_indices_
# Out:
# array([[ 0.69227545,  0.00587129],
#        [-0.57415421,  0.01447164],
#        [ 0.43703147, -0.02646763],
#        [ 0.00949942,  0.59631021],
#        [-0.0031449 , -0.69700708],
#        [-0.00223738,  0.39705269]])

# %%
clf2.visualize()

# %% [markdown]
# # Non-additive Model

# %%
np.random.seed(2020)
n = int(1e4)
x = np.random.normal(0, 1, size=(n, 6))
f = 3*np.pi**(x[:,0]*x[:,1])*np.sqrt(2*np.abs(x[:,2]+1))
noise = np.random.randn(n)
y = f + noise

# %%
clf3 = PPRRegressor(nterms=2,optlevel=2)
clf3.fit(x,y)
# Out:
# PPRRegressor(nterms=2)

# %%
clf3.projection_indices_
# Out:
# array([[-7.33109854e-01, -2.04389618e-01],
#        [-6.73886900e-01,  1.40370002e-01],
#        [-2.46339435e-02,  9.31519057e-01],
#        [-3.01651426e-04,  4.60205100e-02],
#        [-1.52387157e-04,  1.10534936e-01],
#        [-8.84276112e-02, -2.37607942e-01]])

# %%
clf3.visualize()
